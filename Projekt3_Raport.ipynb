# %% [markdown]
#  # TECHNIKI PROGRAMOWANIA - projekt 3
#  ### Martyna Penkowska 197926
#  ### Natalia Sampławska 197573
#
# Wykorzystane biblioteki:
# - matplotplusplus (c++)
# - AudioFile (python)
# - opencv

# %% [markdown]
# ## Wizualizacja sygnału
# Przykłady obrazujące zaimplementowaną funkcjonalność wizualizacji sygnału z wykorzystaniem biblioteki AudioFile oraz matplotplusplus

# %%
import scikit_build_example as sbe

sbe.signal_visualization("./AudioFile/examples/test-audio.wav")

# %% [markdown]
# ![Wizualizacja sygnału 1](signal_visualization1.png)

# %%
sbe.signal_visualization("C:\Users\marty\Downloads\wav_mono_16bit_48000.wav")

# %% [markdown]
# ![Wizualizacja sygnału 1](signal_visualization2.png)

# %%
sbe.signal_visualization("C:\Users\marty\Downloads\aiff_stereo_16bit_44100.aif")

# %% [markdown]
# ![Wizualizacja sygnału 1](signal_visualization3.png)

# %% [markdown]
# ## Generowanie sygnału o podanych parametrach
#
# #### sygnał sinusoidalny

# %%
amplitude = 10
frequency = 1
phase = 0
duration = 10
sampleRate = 44100

sbe.signal_generate_sinusoidal(amplitude,frequency,phase,duration,sampleRate)

# %% [markdown]
# ![Wykres sinusa](signal_generate_sinusoidal1.png)

# %%
amplitude = 1
frequency = 5
phase = 45
duration = 20
sampleRate = 500

sbe.signal_generate_sinusoidal(amplitude,frequency,phase,duration,sampleRate)

# %% [markdown]
# ![Wykres sinusa 2](signal_generate_sinusoidal2.png)

# %% [markdown]
# #### sygnał prostokątny

# %%
amplitude = 20
period = 50
duty_cycle = 50
duration = 100
sampleRate = 100

sbe.signal_generate_square_wave(amplitude,period,duration,duty_cycle,sampleRate)

# %% [markdown]
# ![Wykres sygnału prostokątnego](signal_generate_square_wave1.png)

# %% [markdown]
# #### sygnał piłokształtny

# %%
amplitude = 10
frequency = 2
duration = 10
min_value = 0
phase = 0
sample_rate = 400
unit = dB
sbe.saw_wave_generate(amplitude,frequency,duration,min_value,phase,sample_rate,unit)

# %% [markdown]
# ![Wykres sygnału piłokształtnego1](saw_wave_generate1.png)

# %%
amplitude = 10
frequency = 1
duration = 10
min_value = 5
phase = 0
sample_rate = 400
unit = db
sbe.saw_wave_generate(amplitude,frequency,duration,min_value,phase,sample_rate,unit)

# %% [markdown]
# ![Wykres sygnału piłokształtnego2](saw_wave_generate2.png)

# %% [markdown]
# ## Filtracja 1D
# Filtracja dla sygnałów audio

# %%
sbe.oned_filtering("./AudioFile/tests/test-audio/audiocheck.net_sin_10Hz_-3dBFS_3s.wav")

# %% [markdown]
# ![Wykres po filtracji 1D](oned_filtering1.png)

# %% [markdown]
# ## Filtracja 2D
# Filtracja dla obrazów

# %%
sbe.twod_filter("./mayo.jpg", false, 3)

# %% [markdown]
# ![Oryginał](attachment:mayo.jpg)
# ![Po filtracji 2D](output_img.jpg)
